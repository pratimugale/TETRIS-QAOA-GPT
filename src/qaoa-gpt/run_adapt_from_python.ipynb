# %% [markdown]
# # Testing ADAPT.jl interface in python

# %%
import subprocess
import os
from datetime import datetime
from pathlib import Path
import json
from itertools import islice

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cur_input_graphs_dict = json.load(open('graphs_n10_1idx_jl_022625_dict.json'))

# %%
cur_input_graphs_dict['Graph_4_n10_021225']
# Out:
# {'elist': [[1, 2, 0.09],
#   [1, 4, 0.69],
#   [1, 6, 0.51],
#   [1, 10, 0.94],
#   [2, 3, 0.35],
#   [2, 4, 0.82],
#   [2, 6, 0.96],
#   [2, 7, 0.79],
#   [2, 8, 0.38],
#   [2, 10, 0.67],
#   [3, 4, 0.77],
#   [3, 5, 0.56],
#   [4, 7, 0.34],
#   [4, 8, 0.15],
#   [6, 10, 0.73],
#   [7, 9, 0.52],
#   [8, 9, 0.6],
#   [9, 10, 0.66]],
#  'n_nodes': 10}

# %%
from adapt_utils import (
    run_adapt_jl_parallel,
    show_adapt_logs,
    get_combined_res_df
)

# %%
adapt_gpt_dir = Path(
    "/lustre/acslab/users/2288/Quantum_stuff/Adapt_GPT_files/ADAPT_GPT_git/ADAPT-GPT"
)

# %%
adapt_output_dir = "/lustre/acslab/users/2288/Quantum_stuff/results_darwin/qaoa_n10w_python_test_040925"

# %%
logs_list, cur_proc = run_adapt_jl_parallel(
    script_dir=adapt_gpt_dir,
    output_dir=adapt_output_dir,
    input_graphs=adapt_gpt_dir / "graphs_n10_1idx_jl_022625_dict.json",
    n_workers=2,
    graphs_number=5,
    trials_per_graph=1,
    max_params=50,
    gamma_0="gamma0_grid_012325.json",
    pool_name="qaoa_mixer",
    use_floor_stopper=True,
)
# Out:
# Splitting input graphs into 2 parts
# Starting worker 0 on node: r1t00
# Starting worker 1 on node: r1t00

# %%
show_adapt_logs(logs_list, n_lines=20)
# Out:
# Log: worker_r1t00_0
#
# Graph name: Graph_399_n10_021225;
# Number of edges: 17;
# Number of nodes: 10;
# Generator: input_file.
#
# ▷ MQLib
# ▷ Heuristic: BURER2002
# ┌────────┬─────────────┬──────────┐
# │  iter  │    value    │   time   │
# ├────────┼─────────────┼──────────┤
# │      1 │       0.000 │     5.00 │
# │        │      28.000 │     1.00 │
# └────────┴─────────────┴──────────┘
#
# Number of callbacks: 5
# Exact energy (MQLib): -6.56
# Running with optimizer: BFGS
# For QAOA reading gamma_0 values from: gamma0_grid_012325.json
# For QAOA using gamma_0 = 0.01, trial: 1/1, graph N: 2/45
#
# --------------------------------------------------
# Log: worker_r1t00_1
#
# Graph name: Graph_873_n10_021225;
# Number of edges: 40;
# Number of nodes: 10;
# Generator: input_file.
#
# ▷ MQLib
# ▷ Heuristic: BURER2002
# ┌────────┬─────────────┬──────────┐
# │  iter  │    value    │   time   │
# ├────────┼─────────────┼──────────┤
# │      1 │       0.000 │     5.00 │
# │        │      62.000 │     1.00 │
# └────────┴─────────────┴──────────┘
#
# Number of callbacks: 5
# Exact energy (MQLib): -13.24
# Running with optimizer: BFGS
# For QAOA reading gamma_0 values from: gamma0_grid_012325.json
# For QAOA using gamma_0 = 0.01, trial: 1/1, graph N: 1/44
#
# --------------------------------------------------

# %%
show_adapt_logs(logs_list, n_lines=20, pbar_only=True)
# Out:
# Log: worker_r1t00_0
# Graphs on: r1t00; pid: 19268: 22.2%┣███▍           ┫ 10/45 [02:57<11:29, 20s/it]
#
# Log: worker_r1t00_1
# Graphs on: r1t00; pid: 19269: 15.9%┣██▌             ┫ 7/44 [04:43<29:06, 47s/it]

# %%
combined_res_df = get_combined_res_df(
    adapt_output_dir,
    debug_limit=5,
)
# Out:
# Reading ADAPT.jl results from:
# 	 /lustre/acslab/users/2288/Quantum_stuff/results_darwin/qaoa_n10w_python_test_040925
# Opening ADAPT results (qaoa_n10w_python_test_040925): 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 56.97it/s]
# df_list len: 2
# Opening graphs (qaoa_n10w_python_test_040925): 100%|██████████████████████████████████████████████████████| 2/2 [00:00<00:00, 526.86it/s]
# df_list len: 2
# Graphs count:
# g_method
# input_file    54
# Name: count, dtype: int64
# Aggregating results...

# %%
combined_res_df
# Out:
#     graph_num  run  ... n_layers                                        graph_id
# 0           1    1  ...        8   worker_r1t00_pid_19268_ts_25-04-09__08_48_^_1
# 1           1    1  ...       25   worker_r1t00_pid_19269_ts_25-04-09__08_48_^_1
# 2           1    1  ...        7   worker_r1t00_pid_19269_ts_25-04-09__08_48_^_1
# 3           2    1  ...        9   worker_r1t00_pid_19268_ts_25-04-09__08_48_^_2
# 4           2    1  ...        6   worker_r1t00_pid_19269_ts_25-04-09__08_48_^_2
# ..        ...  ...  ...      ...                                             ...
# 57         27    1  ...       25  worker_r1t00_pid_19269_ts_25-04-09__08_48_^_27
# 58         27    1  ...        7  worker_r1t00_pid_19269_ts_25-04-09__08_48_^_27
# 59         28    1  ...       11  worker_r1t00_pid_19269_ts_25-04-09__08_48_^_28
# 60         29    1  ...        7  worker_r1t00_pid_19269_ts_25-04-09__08_48_^_29
# 61         30    1  ...        6  worker_r1t00_pid_19269_ts_25-04-09__08_48_^_30
#
# [62 rows x 33 columns]
